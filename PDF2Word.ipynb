# %% [markdown]
# <a href="https://colab.research.google.com/github/AbanoubIbrahim98/AOU-Chatbot-Dialogflow/blob/main/PDF2Word.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fitz
# !pip install python-docx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.6/95.6 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 34.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 35.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 42.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 528.1/528.1 kB 20.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 5.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install gdown

# %%
import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX
# To: /content/arabic.pdf
# 100%|██████████| 7.54M/7.54M [00:00<00:00, 84.5MB/s]
# '/content/arabic.pdf'

# %%
import fitz  # PyMuPDF
from docx import Document

def pdf_to_word(pdf_path, word_path):
    # Create a new Document
    doc = Document()

    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    # Iterate over each page
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        text = page.get_text("text")

        # Add the text to the Word document
        doc.add_paragraph(text)

    # Save the Word document
    doc.save(word_path)

# Convert the PDF to Word
pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-ff8ea4f7834a> in <cell line: 1>()
# ----> 1 import fitz  # PyMuPDF
#       2 from docx import Document
#       3
#       4 def pdf_to_word(pdf_path, word_path):
#       5     # Create a new Document
#
# /usr/local/lib/python3.10/dist-packages/fitz/__init__.py in <module>
# ----> 1 from frontend import *
#       2 import tools
#       3 import os.path as op
#       4
#       5 __version__ = '0.0.1dev2'
#
# ModuleNotFoundError: No module named 'frontend'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ...

# %%
# Install required libraries
# !pip install fitz
# !pip install python-docx
# !pip install gdown

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Download the PDF file from Google Drive
import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

# Convert PDF to Word
import fitz  # PyMuPDF
from docx import Document

def pdf_to_word(pdf_path, word_path):
    # Create a new Document
    doc = Document()

    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    # Iterate over each page
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        text = page.get_text("text")

        # Add the text to the Word document
        doc.add_paragraph(text)

    # Save the Word document
    doc.save(word_path)

# Convert the PDF to Word
pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

# Download the Word document
from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading...
# From: https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX
# To: /content/arabic.pdf
# 100%|██████████| 7.54M/7.54M [00:00<00:00, 80.0MB/s]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-4740e7e7839f> in <cell line: 18>()
#      16
#      17 # Convert PDF to Word
# ---> 18 import fitz  # PyMuPDF
#      19 from docx import Document
#      20
#
# /usr/local/lib/python3.10/dist-packages/fitz/__init__.py in <module>
# ----> 1 from frontend import *
#       2 import tools
#       3 import os.path as op
#       4
#       5 __version__ = '0.0.1dev2'
#
# ModuleNotFoundError: No module named 'frontend'
#
# ---------------------------------------------------------------------------
# ...

# %%
# Install required libraries
# !pip install PyMuPDF
# !pip install python-docx
# !pip install gdown

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Download the PDF file from Google Drive
import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

# Convert PDF to Word
import fitz  # PyMuPDF
from docx import Document

def pdf_to_word(pdf_path, word_path):
    # Create a new Document
    doc = Document()

    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    # Iterate over each page
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        text = page.get_text("text")

        # Add the text to the Word document
        doc.add_paragraph(text)

    # Save the Word document
    doc.save(word_path)

# Convert the PDF to Word
pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

# Download the Word document
from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 17.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 41.1 MB/s eta 0:00:00
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading...
# From: https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX
# To: /content/arabic.pdf
# 100%|██████████| 7.54M/7.54M [00:00<00:00, 139MB/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-3412aacd7d3e> in <cell line: 42>()
#      40 pdf_path = '/content/arabic.pdf'
#      41 word_path = '/content/arabic.docx'
# ---> 42 pdf_to_word(pdf_path, word_path)
#      43
#      44 # Download the Word document
#
# <ipython-input-7-3412aacd7d3e> in pdf_to_word(pdf_path, word_path)
#      32
#      33         # Add the text to the Word document
# ...

# %%
# Install required libraries
# !pip install PyMuPDF
# !pip install python-docx
# !pip install gdown

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Download the PDF file from Google Drive
import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

# Convert PDF to Word
import fitz  # PyMuPDF
from docx import Document
import re

def clean_text(text):
    # Remove non-printable characters
    return re.sub(r'[^\x20-\x7E\u0600-\u06FF]', '', text)

def pdf_to_word(pdf_path, word_path):
    # Create a new Document
    doc = Document()

    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    # Iterate over each page
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        text = page.get_text("text")
        cleaned_text = clean_text(text)

        # Add the text to the Word document
        doc.add_paragraph(cleaned_text)

    # Save the Word document
    doc.save(word_path)

# Convert the PDF to Word
pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

# Download the Word document
from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading...
# From: https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX
# To: /content/arabic.pdf
# 100%|██████████| 7.54M/7.54M [00:00<00:00, 47.5MB/s]

# %%
# Install required libraries
# !pip install pdfplumber
# !pip install python-docx
# !pip install gdown

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Download the PDF file from Google Drive
import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

# Convert PDF to Word
import pdfplumber
from docx import Document

def pdf_to_word(pdf_path, word_path):
    # Create a new Document
    doc = Document()

    # Open the PDF file
    with pdfplumber.open(pdf_path) as pdf:
        # Iterate over each page
        for page in pdf.pages:
            text = page.extract_text()
            if text:
                # Add the text to the Word document
                doc.add_paragraph(text)

    # Save the Word document
    doc.save(word_path)

# Convert the PDF to Word
pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

# Download the Word document
from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading...
# From: https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX
# To: /content/arabic.pdf
# 100%|██████████| 7.54M/7.54M [00:00<00:00, 156MB/s]

# %%
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
from docx import Document
import io

def pdf_to_word(pdf_path, word_path):
    # Create a new Document
    doc = Document()

    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    # Iterate over each page
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.open(io.BytesIO(pix.pil_tobytes()))

        # Perform OCR on the image
        text = pytesseract.image_to_string(img, lang='ara')

        # Add the text to the Word document
        doc.add_paragraph(text)

    # Save the Word document
    doc.save(word_path)

# Convert the PDF to Word
pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

# Download the Word document
from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-95c68ce9b60e> in <cell line: 2>()
#       1 import fitz  # PyMuPDF
# ----> 2 import pytesseract
#       3 from PIL import Image
#       4 from docx import Document
#       5 import io
#
# ModuleNotFoundError: No module named 'pytesseract'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Install required libraries
# !pip install PyMuPDF
# !pip install python-docx
# !pip install pytesseract
# !apt-get install tesseract-ocr
# !apt-get install libtesseract-dev
# !pip install pillow
# !pip install gdown

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Download the PDF file from Google Drive
import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

# Convert PDF to Word
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
from docx import Document
import io

def pdf_to_word(pdf_path, word_path):
    # Create a new Document
    doc = Document()

    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    # Iterate over each page
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.open(io.BytesIO(pix.pil_tobytes()))

        # Perform OCR on the image
        text = pytesseract.image_to_string(img, lang='ara')

        # Add the text to the Word document
        doc.add_paragraph(text)

    # Save the Word document
    doc.save(word_path)

# Convert the PDF to Word
pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

# Download the Word document
from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 21.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 2.0 MB/s eta 0:00:00
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# ...

# %%
# Install required libraries
# !pip install PyMuPDF
# !pip install python-docx
# !pip install pytesseract
# !apt-get install tesseract-ocr
# !apt-get install libtesseract-dev
# !pip install pillow
# !pip install gdown

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Download the PDF file from Google Drive
import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

# Convert PDF to Word
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
from docx import Document
import io

def pdf_to_word(pdf_path, word_path):
    # Create a new Document
    doc = Document()

    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    # Iterate over each page
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.open(io.BytesIO(pix.tobytes()))

        # Perform OCR on the image
        text = pytesseract.image_to_string(img, lang='ara')

        # Add the text to the Word document
        doc.add_paragraph(text)

    # Save the Word document
    doc.save(word_path)

# Convert the PDF to Word
pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

# Download the Word document
from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading...
# From: https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX
# To: /content/arabic.pdf
# 100%|██████████| 7.54M/7.54M [00:00<00:00, 72.5MB/s]
# ---------------------------------------------------------------------------
# TesseractError                            Traceback (most recent call last)
# <ipython-input-2-3b98d394087e> in <cell line: 53>()
# ...

# %%
# Install required libraries
# !pip install PyMuPDF
# !pip install python-docx
# !pip install pytesseract
# !apt-get install tesseract-ocr
# !apt-get install libtesseract-dev
# !apt-get install tesseract-ocr-ara
# !pip install pillow
# !pip install gdown

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Download the PDF file from Google Drive
import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

# Set the TESSDATA_PREFIX environment variable
import os
os.environ['TESSDATA_PREFIX'] = '/usr/share/tesseract-ocr/4.00/tessdata/'

# Convert PDF to Word
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
from docx import Document
import io

def pdf_to_word(pdf_path, word_path):
    # Create a new Document
    doc = Document()

    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    # Iterate over each page
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.open(io.BytesIO(pix.pil_tobytes()))

        # Perform OCR on the image
        text = pytesseract.image_to_string(img, lang='ara')

        # Add the text to the Word document
        doc.add_paragraph(text)

    # Save the Word document
    doc.save(word_path)

# Convert the PDF to Word
pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

# Download the Word document
from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tesseract-ocr-ara
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 645 kB of archives.
# After this operation, 1,447 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-ara all 1:4.00~git30-7274cfa-1.1 [645 kB]
# Fetched 645 kB in 1s (627 kB/s)
# ...

# %%
# Install required libraries
# !pip install PyMuPDF
# !pip install python-docx
# !pip install pytesseract
# !apt-get install tesseract-ocr
# !apt-get install libtesseract-dev
# !apt-get install tesseract-ocr-ara
# !pip install pillow
# !pip install gdown

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Download the PDF file from Google Drive
import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

# Set the TESSDATA_PREFIX environment variable
import os
os.environ['TESSDATA_PREFIX'] = '/usr/share/tesseract-ocr/4.00/tessdata/'

# Convert PDF to Word
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
from docx import Document
import io

def pdf_to_word(pdf_path, word_path):
    # Create a new Document
    doc = Document()

    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    # Iterate over each page
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()

        # Convert pixmap to Image
        img = Image.open(io.BytesIO(pix.tobytes('png')))  # Save as PNG in memory

        # Perform OCR on the image
        text = pytesseract.image_to_string(img, lang='ara')

        # Add the text to the Word document
        doc.add_paragraph(text)

    # Save the Word document
    doc.save(word_path)

# Convert the PDF to Word
pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

# Download the Word document
from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-ara is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading...
# From: https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX
# To: /content/arabic.pdf
# ...

# %%
# Install required libraries
# !pip install PyMuPDF
# !pip install python-docx
# !pip install pytesseract
# !apt-get install tesseract-ocr
# !apt-get install libtesseract-dev
# !apt-get install tesseract-ocr-ara
# !pip install pillow
# !pip install gdown

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Download the PDF file from Google Drive
import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

# Set the TESSDATA_PREFIX environment variable
import os
os.environ['TESSDATA_PREFIX'] = '/usr/share/tesseract-ocr/4.00/tessdata/'

# Convert PDF to Word
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
from docx import Document
import io

def pdf_to_word(pdf_path, word_path):
    # Create a new Document
    doc = Document()

    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    # Iterate over each page
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()

        # Convert pixmap to Image
        img = Image.open(io.BytesIO(pix.tobytes('png')))  # Save as PNG in memory

        # Perform OCR on the image
        text = pytesseract.image_to_string(img, lang='ara')

        # Add the text to the Word document
        doc.add_paragraph(text)

    # Save the Word document
    doc.save(word_path)

# Convert the PDF to Word
pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

# Download the Word document
from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-ara is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading...
# From: https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX
# To: /content/arabic.pdf
# ...

# %%
# Install required libraries
# !pip install PyMuPDF
# !pip install python-docx
# !pip install pytesseract
# !apt-get install tesseract-ocr
# !apt-get install libtesseract-dev
# !apt-get install tesseract-ocr-ara
# !pip install pillow
# !pip install gdown

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Download the PDF file from Google Drive
import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

# Set the TESSDATA_PREFIX environment variable
import os
os.environ['TESSDATA_PREFIX'] = '/usr/share/tesseract-ocr/4.00/tessdata/'

# Convert PDF to Word
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
from docx import Document
import io
import re

def clean_text(text):
    # Remove non-printable characters
    return re.sub(r'[^\x20-\x7E\u0600-\u06FF]', '', text)

def pdf_to_word(pdf_path, word_path):
    # Create a new Document
    doc = Document()

    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    # Iterate over each page
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()

        # Convert pixmap to Image
        img = Image.open(io.BytesIO(pix.tobytes('png')))  # Save as PNG in memory

        # Perform OCR on the image
        text = pytesseract.image_to_string(img, lang='ara')

        # Clean the extracted text
        cleaned_text = clean_text(text)

        # Add the cleaned text to the Word document
        doc.add_paragraph(cleaned_text)

    # Save the Word document
    doc.save(word_path)

# Convert the PDF to Word
pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

# Download the Word document
from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-ara is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading...
# From: https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX
# To: /content/arabic.pdf
# ...

# %%
# Install required libraries
# !pip install PyMuPDF
# !pip install python-docx
# !pip install pytesseract
# !apt-get install tesseract-ocr
# !apt-get install libtesseract-dev
# !apt-get install tesseract-ocr-ara
# !pip install pillow
# !pip install gdown

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Download the PDF file from Google Drive
import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

# Set the TESSDATA_PREFIX environment variable
import os
os.environ['TESSDATA_PREFIX'] = '/usr/share/tesseract-ocr/4.00/tessdata/'

# Convert PDF to Word
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
from docx import Document
from docx.shared import Pt
from docx.oxml.ns import qn
import io
import re

def clean_text(text):
    # Remove non-printable characters
    return re.sub(r'[^\x20-\x7E\u0600-\u06FF]', '', text)

def pdf_to_word(pdf_path, word_path):
    # Create a new Document
    doc = Document()

    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    # Iterate over each page
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()

        # Convert pixmap to Image
        img = Image.open(io.BytesIO(pix.tobytes('png')))  # Save as PNG in memory

        # Perform OCR on the image with custom configuration
        custom_config = r'--psm 6'  # Assume a single uniform block of text
        text = pytesseract.image_to_string(img, lang='ara', config=custom_config)

        # Clean the extracted text
        cleaned_text = clean_text(text)

        # Add the cleaned text to the Word document with formatting
        paragraph = doc.add_paragraph(cleaned_text)
        paragraph_format = paragraph.paragraph_format
        paragraph_format.alignment = 3  # Right align text for Arabic

        # Apply basic formatting
        run = paragraph.runs[0]
        run.font.size = Pt(12)
        run.font.name = 'Arial'
        run._element.rPr.rFonts.set(qn('w:eastAsia'), 'Arial')

    # Save the Word document
    doc.save(word_path)

# Convert the PDF to Word
pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

# Download the Word document
from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-ara is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading...
# From: https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX
# To: /content/arabic.pdf
# ...

# %%
# Install required libraries
# !pip install PyMuPDF
# !pip install python-docx
# !pip install pytesseract
# !apt-get install tesseract-ocr
# !apt-get install libtesseract-dev
# !apt-get install tesseract-ocr-ara
# !pip install pillow
# !pip install gdown

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Download the PDF file from Google Drive
import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

# Set the TESSDATA_PREFIX environment variable
import os
os.environ['TESSDATA_PREFIX'] = '/usr/share/tesseract-ocr/4.00/tessdata/'

# Convert PDF to Word
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
from docx import Document
from docx.shared import Pt
from docx.oxml.ns import qn
import io
import re

def clean_text(text):
    # Remove non-printable characters
    return re.sub(r'[^\x20-\x7E\u0600-\u06FF]', '', text)

def pdf_to_word(pdf_path, word_path):
    # Create a new Document
    doc = Document()

    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    # Iterate over each page
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()

        # Convert pixmap to Image
        img = Image.open(io.BytesIO(pix.tobytes('png')))  # Save as PNG in memory

        # Perform OCR on the image with custom configuration
        custom_config = r'--psm 6'  # Assume a single uniform block of text
        text = pytesseract.image_to_string(img, lang='ara', config=custom_config)

        # Clean the extracted text
        cleaned_text = clean_text(text)

        # Add the cleaned text to the Word document with formatting if text is not empty
        if cleaned_text.strip():
            paragraph = doc.add_paragraph(cleaned_text)
            paragraph_format = paragraph.paragraph_format
            paragraph_format.alignment = 3  # Right align text for Arabic

            # Apply basic formatting
            run = paragraph.runs[0]
            run.font.size = Pt(12)
            run.font.name = 'Arial'
            run._element.rPr.rFonts.set(qn('w:eastAsia'), 'Arial')

    # Save the Word document
    doc.save(word_path)

# Convert the PDF to Word
pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

# Download the Word document
from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-ara is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading...
# From: https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX
# To: /content/arabic.pdf
# ...

# %%
# Install required libraries
# !pip install PyMuPDF
# !pip install python-docx
# !pip install pytesseract
# !apt-get install tesseract-ocr
# !apt-get install libtesseract-dev
# !apt-get install tesseract-ocr-ara
# !pip install pillow
# !pip install gdown

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Download the PDF file from Google Drive
import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

# Set the TESSDATA_PREFIX environment variable
import os
os.environ['TESSDATA_PREFIX'] = '/usr/share/tesseract-ocr/4.00/tessdata/'

# Convert PDF to Word
import fitz  # PyMuPDF
import pytesseract
from PIL import Image, ImageEnhance, ImageFilter
from docx import Document
from docx.shared import Pt
from docx.oxml.ns import qn
import io
import re

def clean_text(text):
    # Remove non-printable characters
    return re.sub(r'[^\x20-\x7E\u0600-\u06FF]', '', text)

def preprocess_image(image):
    # Enhance the image for better OCR results
    enhancer = ImageEnhance.Contrast(image)
    enhanced_image = enhancer.enhance(2)
    enhanced_image = enhanced_image.filter(ImageFilter.SHARPEN)
    return enhanced_image

def pdf_to_word(pdf_path, word_path):
    # Create a new Document
    doc = Document()

    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    # Iterate over each page
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()

        # Convert pixmap to Image
        img = Image.open(io.BytesIO(pix.tobytes('png')))  # Save as PNG in memory

        # Preprocess the image
        img = preprocess_image(img)

        # Perform OCR on the image with custom configuration
        custom_config = r'--psm 6'  # Assume a single uniform block of text
        text = pytesseract.image_to_string(img, lang='ara', config=custom_config)

        # Clean the extracted text
        cleaned_text = clean_text(text)

        # Add the cleaned text to the Word document with formatting if text is not empty
        if cleaned_text.strip():
            paragraph = doc.add_paragraph(cleaned_text)
            paragraph_format = paragraph.paragraph_format
            paragraph_format.alignment = 3  # Right align text for Arabic

            # Apply basic formatting
            run = paragraph.runs[0]
            run.font.size = Pt(12)
            run.font.name = 'Arial'
            run._element.rPr.rFonts.set(qn('w:eastAsia'), 'Arial')

    # Save the Word document
    doc.save(word_path)

# Convert the PDF to Word
pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

# Download the Word document
from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-ara is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...
# Mounted at /content/drive
# Downloading...
# From: https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX
# To: /content/arabic.pdf
# 100%|██████████| 7.54M/7.54M [00:00<00:00, 88.9MB/s]
# ---------------------------------------------------------------------------
# ...

# %%
# Install required libraries
# !pip install PyMuPDF
# !pip install python-docx
# !pip install pytesseract
# !apt-get install tesseract-ocr
# !apt-get install libtesseract-dev
# !apt-get install tesseract-ocr-ara
# !pip install pillow
# !pip install gdown

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Download the PDF file from Google Drive
import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

# Set the TESSDATA_PREFIX environment variable
import os
os.environ['TESSDATA_PREFIX'] = '/usr/share/tesseract-ocr/4.00/tessdata/'

# Convert PDF to Word
import fitz  # PyMuPDF
import pytesseract
from PIL import Image, ImageEnhance, ImageFilter
from docx import Document
from docx.shared import Pt
from docx.oxml.ns import qn
import io
import re

def clean_text(text):
    # Remove non-printable characters
    return re.sub(r'[^\x20-\x7E\u0600-\u06FF]', '', text)

def preprocess_image(image):
    # Enhance the image for better OCR results
    enhancer = ImageEnhance.Contrast(image)
    enhanced_image = enhancer.enhance(2)
    enhanced_image = enhanced_image.filter(ImageFilter.SHARPEN)
    return enhanced_image

def pdf_to_word(pdf_path, word_path):
    # Create a new Document
    doc = Document()

    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    # Iterate over each page
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()

        # Convert pixmap to Image
        img = Image.open(io.BytesIO(pix.tobytes('png')))  # Save as PNG in memory

        # Preprocess the image
        img = preprocess_image(img)

        # Perform OCR on the image with custom configuration
        custom_config = r'--psm 6'  # Assume a single uniform block of text
        text = pytesseract.image_to_string(img, lang='ara', config=custom_config)

        # Clean the extracted text
        cleaned_text = clean_text(text)

        # Add the cleaned text to the Word document with formatting if text is not empty
        if cleaned_text.strip():
            paragraph = doc.add_paragraph(cleaned_text)
            paragraph_format = paragraph.paragraph_format
            paragraph_format.alignment = 3  # Right align text for Arabic

            # Apply basic formatting
            run = paragraph.runs[0]
            run.font.size = Pt(12)
            run.font.name = 'Arial'
            run._element.rPr.rFonts.set(qn('w:eastAsia'), 'Arial')

    # Save the Word document
    doc.save(word_path)

# Convert the PDF to Word
pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

# Download the Word document
from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-ara is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading...
# From: https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX
# To: /content/arabic.pdf
# ...

# %%
# Install required libraries
# !pip install google-cloud-vision
# !pip install google-cloud-storage
# !pip install google-auth
# !pip install PyMuPDF
# !pip install python-docx
# !pip install gdown

from google.colab import drive
drive.mount('/content/drive')

import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

from google.cloud import vision
from google.cloud.vision_v1 import types
import io
import fitz  # PyMuPDF
from docx import Document
from docx.shared import Pt
from docx.oxml.ns import qn

def pdf_to_images(pdf_path):
    pdf_document = fitz.open(pdf_path)
    images = []
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.open(io.BytesIO(pix.tobytes('png')))
        images.append(img)
    return images

def detect_text(image):
    client = vision.ImageAnnotatorClient()
    content = io.BytesIO()
    image.save(content, format='PNG')
    image = vision.Image(content=content.getvalue())
    response = client.text_detection(image=image)
    texts = response.text_annotations
    if texts:
        return texts[0].description
    return ''

def clean_text(text):
    return re.sub(r'[^\x20-\x7E\u0600-\u06FF]', '', text)

def pdf_to_word(pdf_path, word_path):
    doc = Document()
    images = pdf_to_images(pdf_path)
    for img in images:
        text = detect_text(img)
        cleaned_text = clean_text(text)
        if cleaned_text.strip():
            paragraph = doc.add_paragraph(cleaned_text)
            paragraph_format = paragraph.paragraph_format
            paragraph_format.alignment = 3
            run = paragraph.runs[0]
            run.font.size = Pt(12)
            run.font.name = 'Arial'
            run._element.rPr.rFonts.set(qn('w:eastAsia'), 'Arial')
    doc.save(word_path)

pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.6/459.6 kB 8.3 MB/s eta 0:00:00
# ...

# %%
# Install required libraries
# !pip install google-cloud-vision
# !pip install google-cloud-storage
# !pip install google-auth
# !pip install PyMuPDF
# !pip install python-docx
# !pip install gdown

from google.colab import drive
drive.mount('/content/drive')

import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

from google.cloud import vision
from google.cloud.vision_v1 import types
import io
import fitz  # PyMuPDF
from docx import Document
from docx.shared import Pt
from docx.oxml.ns import qn

def pdf_to_images(pdf_path):
    pdf_document = fitz.open(pdf_path)
    images = []
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.open(io.BytesIO(pix.tobytes('png')))
        images.append(img)
    return images

def detect_text(image):
    client = vision.ImageAnnotatorClient()
    content = io.BytesIO()
    image.save(content, format='PNG')
    image = vision.Image(content=content.getvalue())
    response = client.text_detection(image=image)
    texts = response.text_annotations
    if texts:
        return texts[0].description
    return ''

def clean_text(text):
    return re.sub(r'[^\x20-\x7E\u0600-\u06FF]', '', text)

def pdf_to_word(pdf_path, word_path):
    doc = Document()
    images = pdf_to_images(pdf_path)
    for img in images:
        text = detect_text(img)
        cleaned_text = clean_text(text)
        if cleaned_text.strip():
            paragraph = doc.add_paragraph(cleaned_text)
            paragraph_format = paragraph.paragraph_format
            paragraph_format.alignment = 3
            run = paragraph.runs[0]
            run.font.size = Pt(12)
            run.font.name = 'Arial'
            run._element.rPr.rFonts.set(qn('w:eastAsia'), 'Arial')
    doc.save(word_path)

pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading...
# From: https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX
# To: /content/arabic.pdf
# 100%|██████████| 7.54M/7.54M [00:00<00:00, 62.3MB/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a97acaa08891> in <cell line: 68>()
#      66 pdf_path = '/content/arabic.pdf'
#      67 word_path = '/content/arabic.docx'
# ---> 68 pdf_to_word(pdf_path, word_path)
#      69
#      70 from google.colab import files
#
# <ipython-input-1-a97acaa08891> in pdf_to_word(pdf_path, word_path)
#      50 def pdf_to_word(pdf_path, word_path):
#      51     doc = Document()
# ---> 52     images = pdf_to_images(pdf_path)
#      53     for img in images:
#      54         text = detect_text(img)
#
# ...

# %%
# Install required libraries
# !pip install google-cloud-vision
# !pip install google-cloud-storage
# !pip install google-auth
# !pip install PyMuPDF
# !pip install python-docx
# !pip install gdown
# !pip install pillow

from google.colab import drive
drive.mount('/content/drive')

import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

from google.cloud import vision
from google.cloud.vision_v1 import types
import io
import fitz  # PyMuPDF
from PIL import Image
from docx import Document
from docx.shared import Pt
from docx.oxml.ns import qn
import re

def pdf_to_images(pdf_path):
    pdf_document = fitz.open(pdf_path)
    images = []
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.open(io.BytesIO(pix.tobytes('png')))
        images.append(img)
    return images

def detect_text(image):
    client = vision.ImageAnnotatorClient()
    content = io.BytesIO()
    image.save(content, format='PNG')
    image = vision.Image(content=content.getvalue())
    response = client.text_detection(image=image)
    texts = response.text_annotations
    if texts:
        return texts[0].description
    return ''

def clean_text(text):
    return re.sub(r'[^\x20-\x7E\u0600-\u06FF]', '', text)

def pdf_to_word(pdf_path, word_path):
    doc = Document()
    images = pdf_to_images(pdf_path)
    for img in images:
        text = detect_text(img)
        cleaned_text = clean_text(text)
        if cleaned_text.strip():
            paragraph = doc.add_paragraph(cleaned_text)
            paragraph_format = paragraph.paragraph_format
            paragraph_format.alignment = 3
            run = paragraph.runs[0]
            run.font.size = Pt(12)
            run.font.name = 'Arial'
            run._element.rPr.rFonts.set(qn('w:eastAsia'), 'Arial')
    doc.save(word_path)

pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading...
# From: https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX
# To: /content/arabic.pdf
# 100%|██████████| 7.54M/7.54M [00:00<00:00, 125MB/s]
# ERROR:grpc._plugin_wrapping:AuthMetadataPluginCallback "<google.auth.transport.grpc.AuthMetadataPlugin object at 0x7bc768a02a40>" raised exception!
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py", line 128, in refresh
#     self._retrieve_info(request)
#   File "/usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py", line 101, in _retrieve_info
#     info = _metadata.get_service_account_info(
#   File "/usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/_metadata.py", line 323, in get_service_account_info
# ...

# %%
# Install required libraries
# !pip install google-cloud-vision
# !pip install google-cloud-storage
# !pip install google-auth
# !pip install PyMuPDF
# !pip install python-docx
# !pip install gdown
# !pip install pillow

from google.colab import drive
drive.mount('/content/drive')

import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

from google.cloud import vision
from google.cloud.vision_v1 import types
import io
import fitz  # PyMuPDF
from PIL import Image
from docx import Document
from docx.shared import Pt
from docx.oxml.ns import qn
import re

def pdf_to_images(pdf_path):
    pdf_document = fitz.open(pdf_path)
    images = []
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.open(io.BytesIO(pix.tobytes('png')))
        images.append(img)
    return images

def detect_text(image):
    client = vision.ImageAnnotatorClient()
    content = io.BytesIO()
    image.save(content, format='PNG')
    image = vision.Image(content=content.getvalue())
    response = client.text_detection(image=image)
    texts = response.text_annotations
    if texts:
        return texts[0].description
    return ''

def clean_text(text):
    return re.sub(r'[^\x20-\x7E\u0600-\u06FF]', '', text)

def pdf_to_word(pdf_path, word_path):
    doc = Document()
    images = pdf_to_images(pdf_path)
    for img in images:
        text = detect_text(img)
        cleaned_text = clean_text(text)
        if cleaned_text.strip():
            paragraph = doc.add_paragraph(cleaned_text)
            paragraph_format = paragraph.paragraph_format
            paragraph_format.alignment = 3
            run = paragraph.runs[0]
            run.font.size = Pt(12)
            run.font.name = 'Arial'
            run._element.rPr.rFonts.set(qn('w:eastAsia'), 'Arial')
    doc.save(word_path)

pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading...
# From: https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX
# To: /content/arabic.pdf
# 100%|██████████| 7.54M/7.54M [00:00<00:00, 93.0MB/s]
# ERROR:grpc._plugin_wrapping:AuthMetadataPluginCallback "<google.auth.transport.grpc.AuthMetadataPlugin object at 0x7bc768a54a90>" raised exception!
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py", line 128, in refresh
#     self._retrieve_info(request)
#   File "/usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py", line 101, in _retrieve_info
#     info = _metadata.get_service_account_info(
#   File "/usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/_metadata.py", line 323, in get_service_account_info
# ...

# %%
# Install required libraries
# !pip install google-cloud-vision
# !pip install google-cloud-storage
# !pip install google-auth
# !pip install PyMuPDF
# !pip install python-docx
# !pip install gdown
# !pip install pillow

from google.colab import drive
drive.mount('/content/drive')

import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

from google.cloud import vision
from google.cloud.vision_v1 import types
import io
import fitz  # PyMuPDF
from PIL import Image
from docx import Document
from docx.shared import Pt
from docx.oxml.ns import qn
import re

def pdf_to_images(pdf_path):
    pdf_document = fitz.open(pdf_path)
    images = []
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.open(io.BytesIO(pix.tobytes('png')))
        images.append(img)
    return images

def detect_text(image):
    client = vision.ImageAnnotatorClient()
    content = io.BytesIO()
    image.save(content, format='PNG')
    image = vision.Image(content=content.getvalue())
    response = client.text_detection(image=image)
    texts = response.text_annotations
    if texts:
        return texts[0].description
    return ''

def clean_text(text):
    return re.sub(r'[^\x20-\x7E\u0600-\u06FF]', '', text)

def pdf_to_word(pdf_path, word_path):
    doc = Document()
    images = pdf_to_images(pdf_path)
    for img in images:
        text = detect_text(img)
        cleaned_text = clean_text(text)
        if cleaned_text.strip():
            paragraph = doc.add_paragraph(cleaned_text)
            paragraph_format = paragraph.paragraph_format
            paragraph_format.alignment = 3
            run = paragraph.runs[0]
            run.font.size = Pt(12)
            run.font.name = 'Arial'
            run._element.rPr.rFonts.set(qn('w:eastAsia'), 'Arial')
    doc.save(word_path)

pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading...
# From: https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX
# To: /content/arabic.pdf
# 100%|██████████| 7.54M/7.54M [00:00<00:00, 122MB/s]
# ERROR:grpc._plugin_wrapping:AuthMetadataPluginCallback "<google.auth.transport.grpc.AuthMetadataPlugin object at 0x7bc768841de0>" raised exception!
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py", line 128, in refresh
#     self._retrieve_info(request)
#   File "/usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py", line 101, in _retrieve_info
#     info = _metadata.get_service_account_info(
#   File "/usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/_metadata.py", line 323, in get_service_account_info
# ...

# %%
# Install required libraries
# !pip install google-cloud-vision
# !pip install google-cloud-storage
# !pip install google-auth
# !pip install PyMuPDF
# !pip install python-docx
# !pip install gdown
# !pip install pillow

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Upload your service account JSON key file
from google.colab import files
files.upload()  # Select your service account JSON key file

# Set the environment variable for authentication
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/content/your_service_account_file.json"  # Update with your JSON key file name

# Download the PDF file from Google Drive
import gdown

url = 'https://drive.google.com/uc?id=1lIu2qiT5yC1A-Hmv6JJd2DjXta2TruUX'
output = '/content/arabic.pdf'
gdown.download(url, output, quiet=False)

from google.cloud import vision
from google.cloud.vision_v1 import types
import io
import fitz  # PyMuPDF
from PIL import Image
from docx import Document
from docx.shared import Pt
from docx.oxml.ns import qn
import re

def pdf_to_images(pdf_path):
    pdf_document = fitz.open(pdf_path)
    images = []
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.open(io.BytesIO(pix.tobytes('png')))
        images.append(img)
    return images

def detect_text(image):
    client = vision.ImageAnnotatorClient()
    content = io.BytesIO()
    image.save(content, format='PNG')
    image = vision.Image(content=content.getvalue())
    response = client.text_detection(image=image)
    texts = response.text_annotations
    if texts:
        return texts[0].description
    return ''

def clean_text(text):
    return re.sub(r'[^\x20-\x7E\u0600-\u06FF]', '', text)

def pdf_to_word(pdf_path, word_path):
    doc = Document()
    images = pdf_to_images(pdf_path)
    for img in images:
        text = detect_text(img)
        cleaned_text = clean_text(text)
        if cleaned_text.strip():
            paragraph = doc.add_paragraph(cleaned_text)
            paragraph_format = paragraph.paragraph_format
            paragraph_format.alignment = 3
            run = paragraph.runs[0]
            run.font.size = Pt(12)
            run.font.name = 'Arial'
            run._element.rPr.rFonts.set(qn('w:eastAsia'), 'Arial')
    doc.save(word_path)

pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      <input type="file" id="files-95e3b30e-a905-43e0-9e02-f6f536c6d5a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-95e3b30e-a905-43e0-9e02-f6f536c6d5a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
from google.cloud import vision
from google.cloud.vision_v1 import types
import io
import fitz  # PyMuPDF
from PIL import Image
from docx import Document
from docx.shared import Pt
from docx.oxml.ns import qn
import re

def pdf_to_images(pdf_path):
    pdf_document = fitz.open(pdf_path)
    images = []
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.open(io.BytesIO(pix.tobytes('png')))
        images.append(img)
    return images

def detect_text(image):
    client = vision.ImageAnnotatorClient()
    content = io.BytesIO()
    image.save(content, format='PNG')
    image = vision.Image(content=content.getvalue())
    response = client.text_detection(image=image)
    texts = response.text_annotations
    if texts:
        return texts[0].description
    return ''

def clean_text(text):
    return re.sub(r'[^\x20-\x7E\u0600-\u06FF]', '', text)

def pdf_to_word(pdf_path, word_path):
    doc = Document()
    images = pdf_to_images(pdf_path)
    for img in images:
        text = detect_text(img)
        cleaned_text = clean_text(text)
        if cleaned_text.strip():
            paragraph = doc.add_paragraph(cleaned_text)
            paragraph_format = paragraph.paragraph_format
            paragraph_format.alignment = 3
            run = paragraph.runs[0]
            run.font.size = Pt(12)
            run.font.name = 'Arial'
            run._element.rPr.rFonts.set(qn('w:eastAsia'), 'Arial')
    doc.save(word_path)

pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# <ipython-input-7-1aa22058e20b> in <cell line: 53>()
#      51 pdf_path = '/content/arabic.pdf'
#      52 word_path = '/content/arabic.docx'
# ---> 53 pdf_to_word(pdf_path, word_path)
#      54
#      55 from google.colab import files
#
# <ipython-input-7-1aa22058e20b> in pdf_to_word(pdf_path, word_path)
#      37     images = pdf_to_images(pdf_path)
#      38     for img in images:
# ---> 39         text = detect_text(img)
#      40         cleaned_text = clean_text(text)
#      41         if cleaned_text.strip():
#
# <ipython-input-7-1aa22058e20b> in detect_text(image)
#      20
#      21 def detect_text(image):
# ---> 22     client = vision.ImageAnnotatorClient()
#      23     content = io.BytesIO()
#      24     image.save(content, format='PNG')
#
# ...

# %%
from google.cloud import vision
from google.cloud.vision_v1 import types
import io
import fitz  # PyMuPDF
from PIL import Image
from docx import Document
from docx.shared import Pt
from docx.oxml.ns import qn
import re

def pdf_to_images(pdf_path):
    pdf_document = fitz.open(pdf_path)
    images = []
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.open(io.BytesIO(pix.tobytes('png')))
        images.append(img)
    return images

def detect_text(image):
    client = vision.ImageAnnotatorClient()
    content = io.BytesIO()
    image.save(content, format='PNG')
    image = vision.Image(content=content.getvalue())
    response = client.text_detection(image=image)
    texts = response.text_annotations
    if texts:
        return texts[0].description
    return ''

def clean_text(text):
    return re.sub(r'[^\x20-\x7E\u0600-\u06FF]', '', text)

def pdf_to_word(pdf_path, word_path):
    doc = Document()
    images = pdf_to_images(pdf_path)
    for img in images:
        text = detect_text(img)
        cleaned_text = clean_text(text)
        if cleaned_text.strip():
            paragraph = doc.add_paragraph(cleaned_text)
            paragraph_format = paragraph.paragraph_format
            paragraph_format.alignment = 3
            run = paragraph.runs[0]
            run.font.size = Pt(12)
            run.font.name = 'Arial'
            run._element.rPr.rFonts.set(qn('w:eastAsia'), 'Arial')
    doc.save(word_path)

pdf_path = '/content/arabic.pdf'
word_path = '/content/arabic.docx'
pdf_to_word(pdf_path, word_path)

from google.colab import files
files.download('/content/arabic.docx')
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# <ipython-input-8-1aa22058e20b> in <cell line: 53>()
#      51 pdf_path = '/content/arabic.pdf'
#      52 word_path = '/content/arabic.docx'
# ---> 53 pdf_to_word(pdf_path, word_path)
#      54
#      55 from google.colab import files
#
# <ipython-input-8-1aa22058e20b> in pdf_to_word(pdf_path, word_path)
#      37     images = pdf_to_images(pdf_path)
#      38     for img in images:
# ---> 39         text = detect_text(img)
#      40         cleaned_text = clean_text(text)
#      41         if cleaned_text.strip():
#
# <ipython-input-8-1aa22058e20b> in detect_text(image)
#      20
#      21 def detect_text(image):
# ---> 22     client = vision.ImageAnnotatorClient()
#      23     content = io.BytesIO()
#      24     image.save(content, format='PNG')
#
# ...
